# %%
# !pip install requests
# !pip install beautifulsoup4
# !pip install pandas
# !pip install openpyxl # May be included in pandas installation

# %%
# Clear variables
# %reset

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
top_level_dict = {
    "Keynote sessions": {
        "Union Symposia (US)": {
            "url": "https://www.egu26.eu/pg/US",
        },
        "Great Debates (GDB)": {
            "url": "https://www.egu26.eu/pg/GDB",
        },
        "Medal & Award Lectures (MAL)": {
            "url": "https://www.egu26.eu/pg/MAL",
        },
    },
    "Union-wide events": {
        "Short Courses (SC)": {
            "url": "https://www.egu26.eu/pg/SC",
        },
        "Education and Outreach Sessions (EOS)": {
            "url": "https://www.egu26.eu/pg/EOS",
        },
    },
    "Community-led": {
        "Splinter meetings": {
            "url": "https://webforms.copernicus.org/EGU26/splinter-meetings",
        },
        "Lectures organized by related scientific societies (LRS)": {
            "url": "https://www.egu26.eu/pg/LRS",
        },
    },
    "Inter- and Transdisciplinary Sessions": {
        "Digital Geosciences": {
            "url": "https://www.egu26.eu/pg/ITS1",
        },
        "Impacts of Climate and Weather in an Inter-and Transdisciplinary context": {
            "url": "https://www.egu26.eu/pg/ITS2",
        },
        "Environment and Society in Geosciences": {
            "url": "https://www.egu26.eu/pg/ITS3",
        },
        "Risk, Resilience, Mitigation and Adaptation": {
            "url": "https://www.egu26.eu/pg/ITS4",
        },
        "General ITS sessions": {
            "url": "https://www.egu26.eu/pg/ITS5",
        },
    },
    "Disciplinary sessions": {
        "Atmospheric Sciences (AS)": {
            "url": "https://www.egu26.eu/pg/AS",
            "num_special": 3,
        },
        "Biogeosciences (BG)": {
            "url": "https://www.egu26.eu/pg/BG",
            "num_special": 2,
        },
        "Climate: Past, Present & Future (CL)": {
            "url": "https://www.egu26.eu/pg/CL",
            "num_special": 2,
        },
        "Cryospheric Sciences (CR)": {
            "url": "https://www.egu26.eu/pg/CR",
            "num_special": 2,
        },
        "Earth Magnetism & Rock Physics (EMRP)": {
            "url": "https://www.egu26.eu/pg/EMRP",
            "num_special": 2,
        },
        "Energy, Resources and the Environment (ERE)": {
            "url": "https://www.egu26.eu/pg/ERE",
            "num_special": 2,
        },
        "Earth & Space Science Informatics (ESSI)":{
            "url": "https://www.egu26.eu/pg/ESSI",
            "num_special": 1,
        },
        "Geodesy (G)": {
            "url": "https://www.egu26.eu/pg/G",
            "num_special": 1,
        },
        "Geodynamics (GD)": {
            "url": "https://www.egu26.eu/pg/GD",
            "num_special": 2,
        },
        "Geosciences Instrumentation & Data Systems (GI)": {
            "url": "https://www.egu26.eu/pg/GI",
            "num_special": 3,
        },
        "Geomorphology (GM)": {
            "url": "https://www.egu26.eu/pg/GM",
            "num_special": 5,
        },
        "Geochemistry, Mineralogy, Petrology & Volcanology (GMPV)": {
            "url": "https://www.egu26.eu/pg/GMPV",
            "num_special": 2,
        },
        "Hydrological Sciences (HS)": {
            "url": "https://www.egu26.eu/pg/HS",
            "num_special": 4,
        },
        "Natural Hazards (NH)":{
            "url": "https://www.egu26.eu/pg/NH",
            "num_special": 6,
        },
        "Nonlinear Processes in Geosciences (NP)": {
            "url": "https://www.egu26.eu/pg/NP",
            "num_special": 2,
        },
        "Ocean Sciences (OS)": {
            "url": "https://www.egu26.eu/pg/OS",
            "num_special": 2,
        },
        "Planetary & Solar System Sciences (PS)": {
            "url": "https://www.egu26.eu/pg/PS",
            "num_special": 6,
        },
        "Seismology (SM)": {
            "url": "https://www.egu26.eu/pg/SM",
            "num_special": 3,
        },
        "Stratigraphy, Sedimentology & Palaeontology (SSP)": {
            "url": "https://www.egu26.eu/pg/SSP",
            "num_special": 3,
        },
        "Soil System Sciences (SSS)":{
            "url": "https://www.egu26.eu/pg/SSS",
            "num_special": 4,
        },
        "Solar-Terrestrial Sciences (ST)":{
            "url": "https://www.egu26.eu/pg/ST",
            "num_special": 2,
        },
        "Tectonics & Structural Geology (TS)": {
            "url": "https://www.egu26.eu/pg/TS",
            "num_special": 2,
        },
    }
}

# %%
# Only works for disciplinary

def get_prog_dict(top_level_dict, dict_item):

    programme_dict = {}

    for programme, item in top_level_dict[dict_item].items():

        print(programme)

        page = requests.get(item['url'])
        soup = BeautifulSoup(page.content, 'html.parser')


        # Add to programme dict
        for pg in soup.find_all(class_='s2simulatorSecondCol'):
            pg_items = pg.get_text(strip=True).split('–')
            pg_code = pg_items[0].strip()
            pg_title = pg_items[1].strip()

            programme_dict[pg_code] = pg_title

    return programme_dict

# %%
programme_dict = get_prog_dict(top_level_dict, "Disciplinary sessions")
# Out:
# Atmospheric Sciences (AS)
# Biogeosciences (BG)
# Climate: Past, Present & Future (CL)
# Cryospheric Sciences (CR)
# Earth Magnetism & Rock Physics (EMRP)
# Energy, Resources and the Environment (ERE)
# Earth & Space Science Informatics (ESSI)
# Geodesy (G)
# Geodynamics (GD)
# Geosciences Instrumentation & Data Systems (GI)
# Geomorphology (GM)
# Geochemistry, Mineralogy, Petrology & Volcanology (GMPV)
# Hydrological Sciences (HS)
# Natural Hazards (NH)
# Nonlinear Processes in Geosciences (NP)
# Ocean Sciences (OS)
# Planetary & Solar System Sciences (PS)
# Seismology (SM)
# Stratigraphy, Sedimentology & Palaeontology (SSP)
# Soil System Sciences (SSS)
# Solar-Terrestrial Sciences (ST)
# Tectonics & Structural Geology (TS)

# %%
programme_dict
# Out:
# {'AS1': 'Meteorology',
#  'AS2': 'Boundary Layer Processes',
#  'AS3': 'Atmospheric Composition, Chemistry and Aerosols',
#  'AS4': 'Interdisciplinary Processes',
#  'AS5': 'Methods and Techniques',
#  'AS6': 'Short Courses',
#  'BG1': 'General Biogeosciences',
#  'BG2': 'Methods in Biogeosciences',
#  'BG3': 'Terrestrial Biogeosciences',
#  'BG4': 'Marine and Freshwater Biogeosciences',
#  'BG5': 'Palaeobiogeosciences',
#  'BG6': 'Geomicrobiomes and their function',
#  'BG7': 'Extraterrestrial and Extreme Environment Biogeosciences',
#  'BG8': 'Biogeosciences, Policy and Society',
#  'BG9': 'Earth System Remote Sensing and Modelling',
#  'BG10': 'Interdisciplinary topics in Biogeosciences',
#  'CL0': 'Inter- and Transdisciplinary Sessions',
#  'CL1.1': 'Past Climate - Deep Time',
#  'CL1.2': 'Past Climate - Last ~2.6 Ma',
#  'CL2': 'Present Climate',
#  'CL3.1': 'Future Climate',
#  'CL3.2': 'Future Climate',
#  'CL4': 'Climate Studies Across Timescales',
#  'CL5': 'Tools for Climate Studies',
#  'CL6': 'Short Courses',
#  'CR1': 'The State of the Cryosphere: Past, Present, Future',
#  'CR2': 'lce sheets, ice shelves and glaciers',
#  'CR3': 'Sea, Lake and River Ice',
#  'CR4': 'Frozen ground, debris-covered glaciers and geomorphology',
#  'CR5': 'Snow and ice: properties, processes, hazards',
#  'CR6': 'Instrumental and paleo-archive observations, analyses, and data-driven methods in the cryospheric sciences',
#  'CR7': 'The Cryosphere in the Earth system: interdisciplinary topics',
#  'CR8': 'Short Courses (SC) Education and Outreach Sessions (EOS)',
#  'EMRP1': 'Rock and Mineral Physics',
#  'EMRP2': 'Geomagnetism',
#  'EMRP3': 'Paleomagnetism and Environmental Magnetism',
#  'ERE1': 'Integrated studies',
#  'ERE2': 'Renewable energy',
#  'ERE3': 'Geo-storage',
#  'ERE4': 'Raw materials and resources',
#  'ERE5': 'Process coupling and monitoring',
#  'ERE6': 'Inter- and Transdisciplinary Sessions (ITS)',
#  'ESSI1': 'Next-Generation Analytics for Scientific Discovery: Data Science, Machine Learning, AI',
#  'ESSI2': 'Data, Software and Computing Infrastructures across Earth and Space Sciences',
#  'ESSI3': 'Open Science Informatics for Earth and Space Sciences',
#  'ESSI4': 'Advanced Technologies and Informatics Enabling Transdisciplinary Science',
#  'ESSI6': 'Short Courses and Education Sessions',
#  'G1': 'Geodetic Theory and Algorithms',
#  'G2': 'Reference Frames and Geodetic Observing Systems',
#  'G3': 'Geodynamics and Earth Fluids',
#  'G4': 'Satellite Gravimetry, Gravity and Magnetic Field Modeling',
#  'G5': 'Geodetic Monitoring of the Atmosphere',
#  'G7': 'Co-organized Sessions and Short Courses',
#  'GD1': 'Earth and Planetary Dynamics, Structure, Composition and Evolution',
#  'GD2': 'Dynamics, Structure and Evolution of Plate Boundaries: Conceptual and Regional Perspectives',
#  'GD3': 'Rheology and Multiscale Mineralogy in Geodynamics',
#  'GD4': 'Modelling, Data collection and Inversion',
#  'GD5': 'Co-listed Tectonophysics sessions relevant to geodynamics',
#  'GD6': 'Co-listed Technical sessions relevant to geodynamics',
#  'GD7': 'Some short courses spotted for you in the program',
#  'GI1': 'New Frontiers in Geoscience Instrumentation',
#  'GI2': 'Data networks and analysis',
#  'GI3': 'Planetary Atmosphere and Ocean instrumentation system',
#  'GI4': 'Earth Observation Systems and Instrumentation',
#  'GI5': 'Investigation Methods for Surface and Subsurface',
#  'GI6': 'Multidisciplinary Sensor Networks for Environmental Applications',
#  'GM1': 'General Geomorphology',
#  'GM2': "Geomorphologists' tools and Methods",
#  'GM3': 'Geomorphology, extreme events, and hazards',
#  'GM4': 'Humans, life, and landscapes',
#  'GM5': 'Erosion, Sediments, Weathering, and Landscapes',
#  'GM6': 'Planetary, Aeolian and Dryland Geomorphology',
#  'GM7': 'Tectonic, Volcanic, and Regional Geomorphology',
#  'GM8': 'Coastal and Submarine Geomorphology',
#  'GM9': 'Glacial, Periglacial, and Cold Regions Geomorphology',
#  'GM10': 'Riverine Geomorphology',
#  'GM11': 'GM-related short courses',
#  'GMPV1': 'New and interdisciplinary applications in geochemistry',
#  'GMPV2': 'Experimental and analytical advances in mineralogy and rock-forming processes',
#  'GMPV3': 'Low-temperature metamorphism and fluid-rock interaction',
#  'GMPV4': 'High-temperature metamorphism and orogenic processes',
#  'GMPV5': 'Building economic ore deposits from source to finish',
#  'GMPV6': 'Critical metals and minerals - formation, recovery, sustainability',
#  'GMPV7': 'Petrologic-geochemical-tectonic evolution of the lithosphere',
#  'GMPV8': 'Mineralogic, chemical and physical structure from mantle to core to surface',
#  'GMPV9': 'Mineralogy, petrology, and geochemistry of the early Earth and analogous (exo)planets',
#  'GMPV10': 'Physical and chemical processes in volcanic systems',
#  'GMPV11': 'Volcano! - hazards, monitoring, human response, mitigation and risk',
#  'GMPV12': 'Computational science and machine learning with GMPV datasets',
#  'GMPV13': 'Interdisciplinary studies with a regional focus',
#  'HS1.1': 'Field hydrology',
#  'HS1.2': 'Cross-cutting hydrological sessions',
#  'HS2.1': 'Catchment hydrology in diverse climates and environments',
#  'HS2.2': 'From observations to concepts to models (in catchment hydrology)',
#  'HS2.3': 'Water quality at the catchment scale',
#  'HS2.4': 'Hydrologic variability and change at multiple scales',
#  'HS2.5': 'Global and (sub)continental hydrology',
#  'HS3': 'Hydroinformatics',
#  'HS4': 'Hydrological forecasting',
#  'HS5.1': 'Water Resources Policy and Management under Uncertainty',
#  'HS5.2': 'Human-Water Systems',
#  'HS5.3': 'Water-Energy-Food-Ecosystem Nexus',
#  'HS5.4': 'Urban Water Management',
#  'HS6': 'Remote sensing and data assimilation',
#  'HS7': 'Precipitation and climate',
#  'HS8.1': 'Subsurface hydrology',
#  'HS8.2': 'Subsurface hydrology',
#  'HS8.3': 'Subsurface hydrology',
#  'HS9': 'Erosion, sedimentation & river processes',
#  'HS10': 'Ecohydrology and Limnology',
#  'HS11': 'Short Courses of specific interest to Hydrological Sciences',
#  'HS12': 'Inter- and transdisciplinary sessions (ITS) related to Hydrological Sciences',
#  'HS13': 'Further sessions of interest to Hydrological Sciences',
#  'NH1': 'Hydro-Meteorological Hazards',
#  'NH2': 'Volcanic Hazards',
#  'NH3': 'Landslide and Snow Avalanche Hazards',
#  'NH4': 'Earthquake Hazards',
#  'NH5': 'Sea & Ocean Hazards',
#  'NH6': 'Remote Sensing, AI, data science & Hazards',
#  'NH7': 'Wildfire Hazards',
#  'NH8': 'Environmental, Biological & Natech Hazards',
#  'NH9': 'Natural Hazards & Society',
#  'NH10': 'Multi-Hazards',
#  'NH11': 'Climate Hazards',
#  'NH13': 'Inter- and Transdisciplinary Sessions',
#  'NH14': 'Further interesting sessions',
#  'NH15': 'Short courses',
#  'NP1': 'Mathematics of Planet Earth',
#  'NP2': 'Dynamical Systems Approaches to Problems in the Geosciences',
#  'NP3': 'Scales, Scaling and Nonlinear Variability',
#  'NP4': 'Time Series and Big Data Methods',
#  'NP5': 'Predictability',
#  'NP6': 'Turbulence, Transport and Diffusion',
#  'NP7': 'Nonlinear Waves',
#  'NP8': 'Emergent Phenomena in the Geosciences',
#  'NP9': 'Short Courses related to NP',
#  'OS1': 'Ocean Circulation and Climate',
#  'OS2': 'Coastal Oceans, Semi-enclosed and Marginal Seas',
#  'OS3': 'Ocean Biogeochemistry and Biology',
#  'OS4': 'Global ocean processes and oceanographic techniques',
#  'PS1': 'Terrestrial planets',
#  'PS2': 'Outer Planets Systems',
#  'PS3': 'Small bodies: asteroids, comets, TNOs, meteors, and interplanetary dust',
#  'PS4': 'Space weather and space weathering',
#  'PS5': 'Exoplanets and Origins and evolution of Planetary Systems',
#  'PS6': 'Life in the Cosmos: Astrobiology and Planetary habitability',
#  'PS7': 'Planetary and Solar System exploration: Mission Support, Instruments, Observations, Applications, Analogues',
#  'SM1': 'General Seismology',
#  'SM2': 'Computational, Theoretical and Data-Intensive Seismology',
#  'SM3': 'Seismic Instrumentation and Infrastructure',
#  'SM4': 'Earthquake Sources, Deformation and Faulting (incl. seismotectonics, geodynamics, earthquake source physics)',
#  'SM5': 'Real-time and Time-dependent Seismology',
#  'SM6': 'Seismic Imaging (from near-surface to global scale, incl. methodological developments)',
#  'SM7': 'Crustal Fluids and Seismicity (incl. induced & triggered seismicity, volcano seismology',
#  'SM8': 'Seismic Hazard (earthquake forecasting, engineering seismology, seismic and multi-hazard assessment)',
#  'SM9': 'Co-organized Sessions',
#  'SSP1': 'General Sessions',
#  'SSP2': 'Stratigraphy, Earth Systems History and Climate Geology',
#  'SSP3': 'Sedimentology: processes, products, diagenesis',
#  'SSP4': 'Palaeontology, Palaeoecology and Evolution of Life',
#  'SSS1': 'History, Education and Society of Soil Science',
#  'SSS2': 'Soil Erosion and Conservation',
#  'SSS3': 'Soil as Records in Time and Space',
#  'SSS4': 'Soil Biology, Microbiology and Biodiversity',
#  'SSS5': 'Soil Chemistry and Organic Matter Dynamics',
#  'SSS6': 'Soil Physics',
#  'SSS7': 'Soil Pollution and Reclamation',
#  'SSS8': 'Soil, Environment and Ecosystem Interactions',
#  'SSS9': 'Soil, Forestry and Agriculture',
#  'SSS10': 'Digital Soils',
#  'SSS11': 'Material and Methods in Soil Sciences',
#  'SSS12': 'Soil Policy and Legislation',
#  'SSS13': 'Short course',
#  'ST1': 'The Sun and Heliosphere',
#  'ST2': 'Magnetosphere',
#  'ST3': 'Ionosphere and Thermosphere',
#  'ST4': 'Space Weather and Space Climate',
#  'TS1': 'Deformation Mechanisms, Rheology, and Rock-Fluid Interactions',
#  'TS2': 'Tectonics of Plate Boundaries: From Rifting to Orogenesis',
#  'TS3': 'Active Tectonics, Seismicity, Kinematics, and Dynamics',
#  'TS4': 'Tectonics and its Interaction with Surface Processes and the Biosphere',
#  'TS6': 'Intraplate Tectonics and Deformation',
#  'TS7': 'Global and Planetary Tectonics and the Evolution of the Earth',
#  'TS8': 'Applications of Tectonics and Structural Geology to Energy Transition, Natural Hazards, and Societal Needs',
#  'TS9': 'General Topics in Tectonics and Structural Geology',
#  'TS10': 'Other Co-organized Sessions and Short Courses'}

# %%
def get_data(top_level_dict, dict_item, programme_dict):

    data = {
        'Category': [],
        'Top Level Session': [],
        'Programme Code': [],
        'Programme Title': [],
        'Programme URL': [],
        'Session Code': [],
        'Session Title': [],
        'Session Co-Organizer': [],
        'Session Conveners': [],
        'Session Orals Schedule': [],
        'Session Posters Onsite Attendance': [],
        'Session Posters Onsite Display': [],
        'Session Posters Virtual Attendance': [],
        'Session Posters Virtual Display': [],
        'Session PICO Schedule': [],
        'Session Other Schedule': []
    }

    for programme, item in top_level_dict[dict_item].items():

        print('\n', programme)

        page = requests.get(item['url'])
        soup = BeautifulSoup(page.content, 'html.parser')

        if 'num_special' in item:
            num_special = item['num_special']
        else:
            num_special = 0

        for block in soup.find_all(class_='co_mto_programme-session-block mb-0')[num_special:]:

            block_code = block.find_all(class_='co_mto_programme-session-block-number-number')[0].get_text(strip=True)
            block_title = ''
            try:
                # block_title = block.find_all(class_='co_mto_programme-session-block-title active')[0].get_text(strip=True)
                block_title = block.find_all(class_='co_mto_programme-session-block-title')[0].get_text(strip=True)
            except:
                print("No block title")

            print(block_code, ' - ', block_title)

            try:
                block_co_organizer = block.find_all(class_='co_mto_programme-session-block-cosponsoring-coorganizing')[0].get_text(strip=True)
            except:
                block_co_organizer = ''

            block_conveners = block.find_all(class_='co_mto_programme-session-block-so')[0].get_text(strip=True)

            orals_schedule = ''
            posters_onsite_attendance = ''
            posters_onsite_display = ''
            posters_virtual_attendance = ''
            posters_virtual_display = ''
            pico_schedule = ''
            other_schedule = ''

            for schedule in block.find_all(class_='mo_scheduling_string'):

                sch_text = schedule.get_text(strip=True)

                if "Orals|Enter live session" in sch_text:
                    orals_schedule = sch_text.split("Orals|Enter live session")[1].strip()
                elif "Posters on site|Attendance" in sch_text:
                    t1 = sch_text.split("|")
                    posters_onsite_attendance = t1[1].split("Attendance")[1].strip()
                    posters_onsite_display = t1[2].split("Display")[1].strip()
                elif "Posters virtual|Enter live session" in sch_text:
                    t2 = sch_text.split("|")
                    posters_virtual_attendance = t2[1].split("Attendance")[1].strip()
                    posters_virtual_display = t2[2].split("Display")[1].strip()
                elif "PICO|Enter live session" in sch_text:
                    pico_schedule = sch_text.split("PICO|Enter live session")[1].strip()
                else:
                    print(sch_text)
                    other_schedule = sch_text.strip()

            data['Category'].append(dict_item)
            data['Top Level Session'].append(programme)

            prog_code = block_code.split('.')[0]
            data['Programme Code'].append(prog_code)
            try:
                data['Programme Title'].append(programme_dict[prog_code])
            except:
                print("Cannot find Programme Code:", prog_code)
                data['Programme Title'].append('')

            data['Programme URL'].append(item['url'])
            data['Session Code'].append(block_code)
            data['Session Title'].append(block_title)
            data['Session Co-Organizer'].append(block_co_organizer)
            data['Session Conveners'].append(block_conveners)
            data['Session Orals Schedule'].append(orals_schedule)
            data['Session Posters Onsite Attendance'].append(posters_onsite_attendance)
            data['Session Posters Onsite Display'].append(posters_onsite_display)
            data['Session Posters Virtual Attendance'].append(posters_virtual_attendance)
            data['Session Posters Virtual Display'].append(posters_virtual_display)
            data['Session PICO Schedule'].append(pico_schedule)
            data['Session Other Schedule'].append(other_schedule)

    return data

# %%
# page = requests.get( top_level_dict['Disciplinary sessions']['Atmospheric Sciences (AS)'] )

# %%
# soup = BeautifulSoup(page.content, 'html.parser')

# %%
# programme_dict = {}

# for pg in soup.find_all(class_='s2simulatorSecondCol'):
#     pg_items = pg.get_text(strip=True).split('–')
#     pg_code = pg_items[0].strip()
#     pg_title = pg_items[1].strip()

#     programme_dict[pg_code] = pg_title

# %%
# for block in soup.find_all(class_='co_mto_programme-session-block mb-0')[2:]:

#     block_code = block.find_all(class_='co_mto_programme-session-block-number-number')[0].get_text(strip=True)
#     block_title = block.find_all(class_='co_mto_programme-session-block-title active')[0].get_text(strip=True)

#     try:
#         block_co_organizer = block.find_all(class_='co_mto_programme-session-block-cosponsoring-coorganizing')[0].get_text(strip=True)
#     except:
#         block_co_organizer = ''

#     block_conveners = block.find_all(class_='co_mto_programme-session-block-so')[0].get_text(strip=True)

#     for schedule in block.find_all(class_='mo_scheduling_string'):

#         sch_text = schedule.get_text(strip=True)

#         if "Orals|Enter live session" in sch_text:
#             orals_schedule = sch_text.split("Orals|Enter live session")[1].strip()
#         elif "Posters on site|Attendance" in sch_text:
#             t1 = sch_text.split("|")
#             posters_onsite_attendance = t1[1].split("Attendance")[1].strip()
#             posters_onsite_display = t1[2].split("Display")[1].strip()
#         elif "Posters virtual|Enter live session" in sch_text:
#             t2 = sch_text.split("|")
#             posters_virtual_attendance = t1[1].split("Attendance")[1].strip()
#             posters_virtual_display = t1[2].split("Display")[1].strip()
#         elif "PICO|Enter live session" in sch_text:
#             pico_schedule = sch_text.split("PICO|Enter live session")[1].strip()
#         else:
#             print(sch_text)
#             other_schedule = sch_text.split("Enter live session")[1].strip()

#     data['Session Code'].append(block_code)
#     data['Session Title'].append(block_title)
#     data['Session Co-Organizer'].append(block_co_organizer)
#     data['Session Conveners'].append(block_conveners)
#     data['Session Orals Schedule'].append(orals_schedule)
#     data['Session Posters Onsite Attendance'].append(posters_onsite_attendance)
#     data['Session Posters Onsite Display'].append(posters_onsite_display)
#     data['Session Posters Virtual Attendance'].append(posters_virtual_attendance)
#     data['Session Posters Virtual Display'].append(posters_virtual_display)

# %%
def check_day(text, day, existing_value):
    if existing_value == 1:
        return 1
    else:
        return 1 if day in text else 0

def get_df(data):
    df = pd.DataFrame(data)

    # List of days of the week
    days_of_week = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri']

    for day in days_of_week:
        df[day] = 0

    # Create new columns for each day of the week
    for day in days_of_week:
        for entry in ['Session Orals Schedule', 'Session Posters Onsite Attendance', 'Session Posters Onsite Display', 'Session Posters Virtual Attendance', 'Session Posters Virtual Display', 'Session PICO Schedule', 'Session Other Schedule']:
            df[day] = df.apply(lambda row: check_day(row[entry], day, row[day]), axis=1)
    
    return df

# %%
data_keynotes = get_data(top_level_dict, 'Keynote sessions', programme_dict)
df_keynotes = get_df(data_keynotes)

data_union_wide = get_data(top_level_dict, 'Union-wide events', programme_dict)
df_union_wide = get_df(data_union_wide)

data_community = get_data(top_level_dict, 'Community-led', programme_dict)
df_community = get_df(data_community)

data_trans = get_data(top_level_dict, 'Inter- and Transdisciplinary Sessions', programme_dict)
df_trans = get_df(data_trans)

data_disciplinary = get_data(top_level_dict, 'Disciplinary sessions', programme_dict)
df_disciplinary = get_df(data_disciplinary)
# Out:
#  Union Symposia (US)
# US1  -  Redefining excellence and academic career pathways in the geosciences
# Cannot find Programme Code: US1
# US2  -  Two Faces of Earth: Hazards and Resources
# Cannot find Programme Code: US2
# US3  -  Seas of the Sun: The Cluster Story
# Cannot find Programme Code: US3
# US4  -  Towards a new RoadMap for Environmental Stewardship and Sustainability in Space Exploration
# Cannot find Programme Code: US4
# US5  -  Have we broken the Earth’s water cycle? Pathways from Planetary Boundaries to local Safe Operating Spaces
# Cannot find Programme Code: US5
# US6  -  Climate change, morals, values and policies
# Cannot find Programme Code: US6
# US7  -  Evidence-based policymaking in an era of increasing climate hazards and risks.
# Cannot find Programme Code: US7
# US8  -  “Greennovation”: how can scientists support the green transition
# Cannot find Programme Code: US8
# US9  -  Methane at 250 – History,  Sources, Sinks and Climate Feedbacks.
# Cannot find Programme Code: US9
# US10  -  The Niscemi landslide (Sicily – Italy): from past to present and future
# Cannot find Programme Code: US10
#
#  Great Debates (GDB)
# GDB1  -  What's next for EDI in these turbulent times?
# Cannot find Programme Code: GDB1
# GDB2  -  The ethics of using Artificial Intelligence in the Geosciences - Opportunities and Risks
# Cannot find Programme Code: GDB2
# GDB3  -  Geoengineering - Overarching Great Debate
# Cannot find Programme Code: GDB3
# GDB4  -  From Honest Brokers to Lobbyists: What Could Be the Role of Scientists in Different Contexts and Countries?
# Cannot find Programme Code: GDB4
# GDB5  -  Forecasting the Unprecedented: Machine Learning vs. Physics in Climate Science and the EU’s Strategic Position
# Cannot find Programme Code: GDB5
# GDB6  -  Overlooked in models?: The dynamics of terrestrial ecosystems and their coupled feedbacks on hydrology, biogeochemistry and geomorphology
# Cannot find Programme Code: GDB6
# GDB7  -  The future of scientific publishing – do we need scientific journals?
# Cannot find Programme Code: GDB7
#
#  Medal & Award Lectures (MAL)
# MAL1  -  Alexander von Humboldt Medal Lecture by Walter W. Immerzeel
# Cannot find Programme Code: MAL1
# MAL2  -  Alfred Wegener Medal Lecture by Thomas F. Stocker
# Cannot find Programme Code: MAL2
# MAL3  -  Arthur Holmes Medal Lecture by Michael Paul Searle
# Cannot find Programme Code: MAL3
# MAL4  -  Jean Dominique Cassini Medal Lecture by  Martin Bizzarro
# Cannot find Programme Code: MAL4
# MAL6-NH  -  Arne Richter Award for Outstanding ECS Lecture by  Nivedita Sairam
# Cannot find Programme Code: MAL6-NH
# MAL9  -  Angela Croome Award Lecture by Joshua Howgego
# Cannot find Programme Code: MAL9
# MAL10  -  Champion(s) for Equality, Diversity and Inclusion Award Lecture by Rie S. Hori
# Cannot find Programme Code: MAL10
# MAL11  -  Katia and Maurice Krafft Award Lecture by Philip Heron
# Cannot find Programme Code: MAL11
# MAL12  -  EGU Science for Policy Award Lecture by the Science for Policy Team of the Finnish Academy of Science and Letters
# Cannot find Programme Code: MAL12
# MAL13-SSS  -  Alina Kabata-Pendias Medal Lecture by Bettina Weber
# Cannot find Programme Code: MAL13-SSS
# MAL14-GD  -  Augustus Love Medal Lecture by Saskia Goes and GD Division Outstanding ECS Award Lecture by Siavash Ghelichkhan
# Cannot find Programme Code: MAL14-GD
# MAL15-SM  -  Beno Gutenberg Medal Lecture by Satoshi Ide and SM Division Outstanding ECS Award Lecture by Kurama Okubo
# Cannot find Programme Code: MAL15-SM
# MAL16-GI  -  Christiaan Huygens Medal Lecture by Vijay Prasad Dimri and GI Division Outstanding ECS Award Lecture by Andrea Barone
# Cannot find Programme Code: MAL16-GI
# MAL17-PS  -  David Bates Medal Lecture by Patrick Irwin and PS Division Outstanding ECS Award Lecture by Hamish C.F.C. Hay
# Cannot find Programme Code: MAL17-PS
# MAL18-ST  -  Hannes Alfvén Medal Lecture by Zdeněk Němeček and Jana Šafránková
# Cannot find Programme Code: MAL18-ST
# MAL19-CL  -  Hans Oeschger Medal Lecture by Friederike E.L. Otto
# Cannot find Programme Code: MAL19-CL
# MAL20-HS  -  Henry Darcy Medal Lecture by Sally E. Thompson
# Cannot find Programme Code: MAL20-HS
# MAL21-SSP  -  Jean Baptiste Lamarck Medal Lecture by Benjamin Bomfleur
# Cannot find Programme Code: MAL21-SSP
# MAL22-HS  -  John Dalton Medal Lecture by Thorsten Wagener
# Cannot find Programme Code: MAL22-HS
# MAL23-CR  -  Julia and Johannes Weertman Medal Lecture by Olaf Eisen and Arne Richter Award for Outstanding ECS Lecture by Kaitlin Naughten
# Cannot find Programme Code: MAL23-CR
# MAL24-NP  -  Lewis Fry Richardson Medal Lecture by Anastasios A. Tsonis and Arne Richter Award for Outstanding ECS Lecture by Francisco de Melo Viríssimo
# Cannot find Programme Code: MAL24-NP
# MAL25-EMRP  -  Louis Néel Medal Lecture by Francois Renard and EMRP Division Outstanding ECS Award Lecture by Lucille Carbillet
# Cannot find Programme Code: MAL25-EMRP
# MAL26-TS  -  Marie Tharp Medal Lecture by Christian Teyssier
# Cannot find Programme Code: MAL26-TS
# MAL27-SSS  -  Philippe Duchaufour Medal Lecture by Cornelia Rumpel and SSS Division Outstanding ECS Award Lecture by Layla Márquez San Emeterio
# Cannot find Programme Code: MAL27-SSS
# MAL28-NH  -  Plinius Medal Lecture by Amir AghaKouchak
# Cannot find Programme Code: MAL28-NH
# MAL29-GM  -  Ralph Alger Bagnold Medal Lecture by Maarten G. Kleinhans
# Cannot find Programme Code: MAL29-GM
# MAL30-GMPV  -  Robert Wilhelm Bunsen Medal Lecture by Giovanni Chiodini
# Cannot find Programme Code: MAL30-GMPV
# MAL31-NH  -  Sergey Soloviev Medal Lecture by Gerassimos A. Papadopoulos
# Cannot find Programme Code: MAL31-NH
# MAL32-G  -  Vening Meinesz Medal Lecture by Frank Flechtner and G Division Outstanding ECS Award Lecture by Eva Börgens
# Cannot find Programme Code: MAL32-G
# MAL33-AS  -  Vilhelm Bjerknes Medal Lecture by Jonathan Williams
# Cannot find Programme Code: MAL33-AS
# MAL34-BG  -  Vladimir Ivanovich Vernadsky Medal Lecture by Thomas Stephen Bianchi and BG Division Outstanding ECS Award Lecture by Anne Klosterhalfen
# Cannot find Programme Code: MAL34-BG
# MAL35-AS  -  AS Division Outstanding ECS Award Lecture by Eva Pfannerstill
# Cannot find Programme Code: MAL35-AS
# MAL39-ERE  -  ERE Division Outstanding ECS Award Lecture by Wenzhuo Cao
# Cannot find Programme Code: MAL39-ERE
# MAL43-GM  -  GM Division Outstanding ECS Award Lecture by Dongfeng Li
# Cannot find Programme Code: MAL43-GM
# MAL44-HS  -  HS Division Outstanding ECS Award Lecture by Larisa Tarasova
# Cannot find Programme Code: MAL44-HS
# MAL45-OS  -  OS Division Outstanding ECS Award Lecture by Tillys Petit
# Cannot find Programme Code: MAL45-OS
# MAL48-SSP  -  SSP Division Outstanding ECS Award Lecture by Matthias Sinnesael
# Cannot find Programme Code: MAL48-SSP
# MAL50-ST  -  ST Division Outstanding ECS Award Lecture by Samuel Badman
# Cannot find Programme Code: MAL50-ST
#
#  Short Courses (SC)
# SC1.1  -  How to navigate EGU: tips and tricks
# Cannot find Programme Code: SC1
# SC1.2  -  How to navigate EGU as a neurodivergent participant
# Cannot find Programme Code: SC1
# SC1.3  -  Best Practices for Early Career Researcher (ECR) Engagement and Empowerment
# Cannot find Programme Code: SC1
# SC1.4  -  How Are Postdocs Doing? Rethinking the Postdoctoral Experience in Geosciences
# Cannot find Programme Code: SC1
# SC1.5  -  Breaking Boundaries: Mastering Research Proposals – Insights and Strategies from a Global South Perspective
# Cannot find Programme Code: SC1
# SC1.6  -  Mind your head: How to navigate academic conflict
# Cannot find Programme Code: SC1
# SC1.7  -  Best Practices to Building an Effective Code of Conduct
# Cannot find Programme Code: SC1
# SC1.8  -  Mentorship in Motion: Navigating the Career Ladder with Guidance and Growth
# Cannot find Programme Code: SC1
# SC1.9  -  Psychological tools to preserve mental health while navigating the challenges of a research career
# Cannot find Programme Code: SC1
# SC1.10  -  Creating safe spaces in academia: recognizing and responding to harassment
# Cannot find Programme Code: SC1
# SC1.11  -  Grappling with geoethical values and principles: A hands-on, participatory workshop
# Cannot find Programme Code: SC1
# SC1.12  -  European Research Council (ERC) Funding Opportunities
# Cannot find Programme Code: SC1
# SC1.13  -  Careers inside and outside of academia: Panel discussion
# Cannot find Programme Code: SC1
# SC1.14  -  Transferable skills: what are they and do I have them?
# Cannot find Programme Code: SC1
# SC1.15  -  Managing Academia and Parenting in society today
# Cannot find Programme Code: SC1
# SC1.16  -  The LGBT Pride group at EGU: How to find and build your community
# Cannot find Programme Code: SC1
# SC1.17  -  Invited to interview? Prepare for success with job applications and interviews in industry and academia
# Cannot find Programme Code: SC1
# SC2.1  -  Compound Events and Multi-Hazard Analytics
# Cannot find Programme Code: SC2
# SC2.2  -  Integration of eDNA in Geoscience Research
# Cannot find Programme Code: SC2
# SC2.3  -  Radiocarbon Dating Concepts and Practical Guide
# Cannot find Programme Code: SC2
# SC2.4  -  Co-creation in Practice: Challenges, Successes, and Strategies in Water Research
# Cannot find Programme Code: SC2
# SC2.5  -  Data compression and reduction for Earth System Sciences datasets in practice
# Cannot find Programme Code: SC2
# SC2.6  -  Use and Applications of Ensemble Forecasting Methods for  Flood Forecasting and Reservoir Operations.
# Cannot find Programme Code: SC2
# SC2.7  -  Getting Started with Data Assimilation: Theory and Application
# Cannot find Programme Code: SC2
# SC2.8  -  Analogues and Dynamical Systems Indices: A Unified Approach for Predictability, Attribution, and Impacts of Climate Extremes
# Cannot find Programme Code: SC2
# SC2.9  -  Navigating big weather data: An introduction to ECMWF’s MARS data archive
# Cannot find Programme Code: SC2
# SC2.10  -  Sustainable Research Software
# Cannot find Programme Code: SC2
# SC2.11  -  Supporting the understanding and reuse of reproducible analysis workflows
# Cannot find Programme Code: SC2
# SC2.12  -  Good Programming Practices for Research: Essential Rules for Efficient Programming
# Cannot find Programme Code: SC2
# SC2.13  -  Hands-on introduction to git for version-control of code
# Cannot find Programme Code: SC2
# SC2.14  -  Building APIs with Django for environmental applications
# Cannot find Programme Code: SC2
# SC2.15  -  Modeling annual burn probability using the SCENFIRE package
# Cannot find Programme Code: SC2
# SC2.16  -  The (Enhanced) Impact Chains toolkit: Short course on untangling multi-hazard disasters
# Cannot find Programme Code: SC2
# SC2.17  -  Hands-on 3D landslide mapping
# Cannot find Programme Code: SC2
# SC2.18  -  Harnessing the ENVRI-Hub: data, tools, and services for interdisciplinary research
# Cannot find Programme Code: SC2
# SC2.19  -  Discover data, repositories and learning materials - advance your research by using open ESS services
# Cannot find Programme Code: SC2
# SC2.20  -  Introducing GEOtop and GEOframe: Open Source Tools for Modeling Snow Dominated Catchments
# Cannot find Programme Code: SC2
# SC2.21  -  Harnessing cross-disciplinary research - Jupyter Notebooks in EPOS
# Cannot find Programme Code: SC2
# SC2.22  -  See the Flames from Space: Hands-on Wildfire Visualization with EUMETView and GIS
# Cannot find Programme Code: SC2
# SC2.23  -  Using Machine Learning to downscale climate scenarios
# Cannot find Programme Code: SC2
# SC2.24  -  AI on Spatio-Temporal Data: Why does it have to be so complicated?
# Cannot find Programme Code: SC2
# SC2.25  -  From classical Geodetic Theory to modern Machine Learning: an introduction.
# Cannot find Programme Code: SC2
# SC2.26  -  Best practices in deep learning for oceanography
# Cannot find Programme Code: SC2
# SC2.27  -  Processing and visualizing 2-D datasets using the PyAnalySeries software for research and teaching
# Cannot find Programme Code: SC2
# SC2.28  -  How to feed Machine Learning algorithms with proper metrics?
# Cannot find Programme Code: SC2
# SC2.29  -  Big Questions in the Anthropocene
# Cannot find Programme Code: SC2
# SC3.1  -  Meet the Austrian Parliament Science for Policy Staff
# Cannot find Programme Code: SC3
# SC3.2  -  Instruments and Initiatives for Policy Engagement
# Cannot find Programme Code: SC3
# SC3.3  -  New Toolkits – the destabilisation of science and what we can do about it
# Cannot find Programme Code: SC3
# SC3.4  -  Science Diplomacy: What is it and how to engage
# Cannot find Programme Code: SC3
# SC3.5  -  Reproducible by design: how to make sure anyone can re-run your study, even without your computer.
# Cannot find Programme Code: SC3
# SC3.6  -  DataViz: Visualise your data effectively and avoid common pitfalls
# Cannot find Programme Code: SC3
# SC3.7  -  Growing Curiosity – Geoscience Education for Children
# Cannot find Programme Code: SC3
# SC3.8  -  Communicating Your Science: Blogs, Press Releases, and Media Interviews
# Cannot find Programme Code: SC3
# SC3.9  -  Scared, but prepared: Present with confidence
# Cannot find Programme Code: SC3
# SC3.10  -  Elevate your Pitch: Developing Engaging Short Scientific Presentations
# Cannot find Programme Code: SC3
# SC3.11  -  How to publish my geoscience communication work: A hands-on, participatory workshop.
# Cannot find Programme Code: SC3
# SC3.12  -  Meet the Editors: How to peer-review – Fundamentals & EGU’s model
# Cannot find Programme Code: SC3
# SC3.13  -  Get your writing right: A hands-on, participatory workshop to help improve writing skills
# Cannot find Programme Code: SC3
# SC4.1  -  Geology 101: An introduction for non-geologists
# Cannot find Programme Code: SC4
# SC4.2  -  Exoplanets 101
# Cannot find Programme Code: SC4
# SC4.3  -  Geodesy 101: A crash course for non-geodesists
# Cannot find Programme Code: SC4
# SC4.4  -  Seismology 101: An introduction to seismology for non-seismologists
# Cannot find Programme Code: SC4
#
#  Education and Outreach Sessions (EOS)
# EOS0.1  -  Reimagining Geoscience Education: Engaging with the younger generations
# Cannot find Programme Code: EOS0
# EOS1.1  -  Science and Society: Science Communication Practice, Research, and Reflection
# Cannot find Programme Code: EOS1
# EOS1.2  -  Building Bridges: Art-Science Collaborations for a Sustainable Future
# Cannot find Programme Code: EOS1
# EOS1.3  -  Games for Geoscience
# Cannot find Programme Code: EOS1
# EOS1.4  -  How to communicate uncertainty to non-experts
# Cannot find Programme Code: EOS1
# NH9.13  -  Innovative Approaches to Hazards, Risk and Disaster Education and Communication
# EOS1.5  -  Immersive Geoscience: Virtual, Augmented and Mixed Reality in Education, Outreach and Research
# Cannot find Programme Code: EOS1
# EOS1.6  -  Up-Goer Five Challenge: Making Big Ideas Simpler by Talking About Them in Words We Use a Lot
# Cannot find Programme Code: EOS1
# HS5.2.3  -  Co-creation in Hydrology and Water Resources Management
# Cannot find Programme Code: HS5
# SC1.1  -  How to navigate EGU: tips and tricks
# Cannot find Programme Code: SC1
# SC1.5  -  Breaking Boundaries: Mastering Research Proposals – Insights and Strategies from a Global South Perspective
# Cannot find Programme Code: SC1
# SC3.7  -  Growing Curiosity – Geoscience Education for Children
# Cannot find Programme Code: SC3
# SC3.13  -  Get your writing right: A hands-on, participatory workshop to help improve writing skills
# Cannot find Programme Code: SC3
# SC3.10  -  Elevate your Pitch: Developing Engaging Short Scientific Presentations
# Cannot find Programme Code: SC3
# SC3.11  -  How to publish my geoscience communication work: A hands-on, participatory workshop.
# Cannot find Programme Code: SC3
# SC3.12  -  Meet the Editors: How to peer-review – Fundamentals & EGU’s model
# Cannot find Programme Code: SC3
# SC3.8  -  Communicating Your Science: Blogs, Press Releases, and Media Interviews
# Cannot find Programme Code: SC3
# SC3.6  -  DataViz: Visualise your data effectively and avoid common pitfalls
# Cannot find Programme Code: SC3
# SC3.5  -  Reproducible by design: how to make sure anyone can re-run your study, even without your computer.
# Cannot find Programme Code: SC3
# SC3.9  -  Scared, but prepared: Present with confidence
# Cannot find Programme Code: SC3
# EOS2.1  -  Open session on Teaching and Learning in Higher Education
# Cannot find Programme Code: EOS2
# EOS2.4  -  Geospatial Computational Education in the Era of Big Earth Data
# Cannot find Programme Code: EOS2
# EOS2.7  -  Learning to fly: Inviting diverse Early Career Perspectives on Research Challenges
# Cannot find Programme Code: EOS2
# SC2.4  -  Co-creation in Practice: Challenges, Successes, and Strategies in Water Research
# Cannot find Programme Code: SC2
# EOS3.1  -  Women in Geoscience: Experiences and Challenges
# Cannot find Programme Code: EOS3
# EOS3.2  -  10th anniversary of the session Promoting and supporting inclusive excellence in the geosciences
# Cannot find Programme Code: EOS3
# EOS4.1  -  Geoethics: Linking Geoscience Knowledge, Ethical Responsibility, and Action
# Cannot find Programme Code: EOS4
# EOS4.3  -  Celebrating 25 Years of Interactive Open Access Publishing: Transparent, Community-driven, Not-for profit
# Cannot find Programme Code: EOS4
# EOS4.4  -  BUGS: Blunders, Unexpected Glitches, and Surprises
# Cannot find Programme Code: EOS4
# EOS4.6  -  Strengthening Policy Through Science: Insights from the interface
# Cannot find Programme Code: EOS4
# EOS4.7  -  Bridging the gap between climate science and legal practice: informing laws and litigation
# Cannot find Programme Code: EOS4
# HS5.1.5  -  Cooperation, Equitable and Multisectoral Water Resources Management under Climate Change: From Research to Capacity Development
# Cannot find Programme Code: HS5
# SC1.11  -  Grappling with geoethical values and principles: A hands-on, participatory workshop
# Cannot find Programme Code: SC1
# SC3.3  -  New Toolkits – the destabilisation of science and what we can do about it
# Cannot find Programme Code: SC3
# SC3.4  -  Science Diplomacy: What is it and how to engage
# Cannot find Programme Code: SC3
# SC3.2  -  Instruments and Initiatives for Policy Engagement
# Cannot find Programme Code: SC3
# SC3.1  -  Meet the Austrian Parliament Science for Policy Staff
# Cannot find Programme Code: SC3
# EOS5.1  -  Supporting Earth Science in school education
# Cannot find Programme Code: EOS5
# EOS5.3  -  GIFT - Geoscience Information for Teachers (by invitation only)
# Cannot find Programme Code: EOS5
# EOS5.4  -  GIFT - Geoscience Information For Teachers - Hands-on session (by invitation only)
# Cannot find Programme Code: EOS5
# EOS5.5  -  GIFT - Geoscience Information For Teachers – Projects on Natural Hazards, Human Impact and Earth's Resources at School
# Cannot find Programme Code: EOS5
#
#  Splinter meetings
#
#  Lectures organized by related scientific societies (LRS)
# LRS1  -  20th C.F. Gauss Lecture by Rebekka Steffen
# Cannot find Programme Code: LRS1
# LRS2  -  AGU-VGP Kuno Award Lectures by Michelle Muth and Wenzhong Wang
# Cannot find Programme Code: LRS2
# LRS3  -  Copernicus Medal Lecture by Ben Poulter
# Cannot find Programme Code: LRS3
#
#  Digital Geosciences
# ITS1.2/NH13.7  -  Leveraging AI & HPC for Natural Hazard Resilience: From Enhanced Detection, Forecasting, and Modelling in Time-Critical Scenarios to Inform Climate-Adaptive Response.
# Cannot find Programme Code: ITS1
# ITS1.6/ESSI1.6  -  Generative AI, Agentic Systems and Hybrid Intelligence in Geosciences: Leveraging AI to Empower Human Insight
# Cannot find Programme Code: ITS1
# ITS1.7/CL0.3  -  Advancing Earth System Models using Machine Learning
# Cannot find Programme Code: ITS1
# ITS1.8/CL0.2  -  Machine Learning for Climate Science
# Cannot find Programme Code: ITS1
# ITS1.9/OS4.1  -  Machine Learning for Ocean Science
# Cannot find Programme Code: ITS1
# ITS1.10/BG10.6  -  Machine learning and hybrid modelling for carbon cycle science, monitoring and carbon market policy
# Cannot find Programme Code: ITS1
# ITS1.11/ESSI1.10  -  Digital Twins in Earth Systems: Bridging Data and Predictive Modelling for Resilient Futures
# Cannot find Programme Code: ITS1
# ITS1.13/AS5.5  -  Downscaling: methods, applications and added value
# Cannot find Programme Code: ITS1
# ITS1.14/GI1  -  Data-Driven Planning in Changing Environments: From Population Grids to Management of Outdoor Recreation
# Cannot find Programme Code: ITS1
# ITS1.15/NH13.1  -  Natural Language Processing and Large Language Models in Geosciences, Natural Hazards and Hydrology
# Cannot find Programme Code: ITS1
# ITS1.19/AS4.8  -  Advancing Environmental sciences with Innovation and Research Infrastructures
# Cannot find Programme Code: ITS1
# ITS1.20/ESSI4.3  -  Co-Creating Climate Services: Linking Essential Variables with Actionable Decision Support
# Cannot find Programme Code: ITS1
# ITS1.21/ESSI4.5  -  Inter- and Transdisciplinary Studies of the Geosphere: experiences, challenges and new perspectives  worldwide
# Cannot find Programme Code: ITS1
#
#  Impacts of Climate and Weather in an Inter-and Transdisciplinary context
# ITS2.1/CL0.7  -  Compound weather and climate events
# Cannot find Programme Code: ITS2
# ITS2.2/G3.2  -  The omnipresent glacial isostatic adjustment process while investigating the Earth system
# Cannot find Programme Code: ITS2
# ITS2.4/CL0.18  -  Climate Change and Global Health Risks from Interdisciplinary Perspectives
# Cannot find Programme Code: ITS2
# ITS2.5/CL0.5  -  AMOC changes and impacts on physical, biogeochemical, and societal systems
# Cannot find Programme Code: ITS2
# ITS2.6/BG10.9  -  Climate change impacts on ecosystems: Disturbance regimes, extreme weather, vulnerability, and resilience
# Cannot find Programme Code: ITS2
# ITS2.7/NH13.3  -  Climate hazards and socioeconomic inequality across scales
# Cannot find Programme Code: ITS2
# ITS2.8/NH13.12  -  Bridging natural and social sciences to study societal responses to extreme weather events
# Cannot find Programme Code: ITS2
# ITS2.11/CL0.1  -  Past to future - towards fully paleo-informed future climate projections
# Cannot find Programme Code: ITS2
#
#  Environment and Society in Geosciences
# ITS3.2/SSP1.8  -  Navigating the Anthropocene towards habitability: linking research on Earth system processes and societal dynamics, values and policies
# Cannot find Programme Code: ITS3
# ITS3.3/CL0.24  -  Merging Social Science and Environmental Studies
# Cannot find Programme Code: ITS3
# ITS3.4/GM3  -  Mythogenic landscapes: From Geodiversity through Geomythology to Geoheritage
# Cannot find Programme Code: ITS3
# ITS3.6/ERE6.5  -  Advancing Justice and Social Science Integration in Climate Modeling
# Cannot find Programme Code: ITS3
# ITS3.7/BG10.5  -  Collaborative efforts to better understand how planetary changes affect health and wellbeing
# Cannot find Programme Code: ITS3
# ITS3.8/ERE6.6  -  Decision Support Systems for Ecosystem Services
# Cannot find Programme Code: ITS3
# ITS3.12/NP8.8  -  Urban geosciences: modelling and monitoring complex cities
# Cannot find Programme Code: ITS3
# ITS3.14/HS12.4  -  Advances in plastic pollution monitoring across the Geosphere
# Cannot find Programme Code: ITS3
# ITS3.15/NH13.2  -  Global Environmental Change in Mountain Social-Ecological Systems: Advances and new perspectives
# Cannot find Programme Code: ITS3
# ITS3.18/BG10.16  -  Networking, training, education and public engagement in interdisciplinary fields
# Cannot find Programme Code: ITS3
#
#  Risk, Resilience, Mitigation and Adaptation
# ITS4.1/NP8.9  -  Tipping Points in the Earth System
# Cannot find Programme Code: ITS4
# ITS4.2/CL0.12  -  Earth resilience in the Anthropocene: from tipping points to planetary boundaries and human-Earth system interactions
# Cannot find Programme Code: ITS4
# ITS4.4/CL0.11  -  Interdisciplinary approaches to addressing complex climate risks
# Cannot find Programme Code: ITS4
# ITS4.7/CL0.15  -  Measuring climate adaptation: from processes and outputs to outcomes and impacts
# Cannot find Programme Code: ITS4
# ITS4.8/NH13.10  -  Nature-based Solutions for climate change adaptation
# Cannot find Programme Code: ITS4
# ITS4.9/HS12.5  -  Nature-based solutions for climate-resilient landscapes: bridging science, practice, and policy.
# Cannot find Programme Code: ITS4
# ITS4.10/HS12.11  -  Mainstreaming Nature-Based Solutions for water resilience: turning the EU Strategy into action
# Cannot find Programme Code: ITS4
# ITS4.11/NH13.9  -  Nature-based and community-led strategies for disaster risk reduction, ecosystem restoration (land, water and biodiversity), and climate change adaptation in socio-ecological systems
# Cannot find Programme Code: ITS4
# ITS4.13/GM1  -  Nature-based coastal solutions: integrating geoscience, engineering, and societal perspectives on successes, failures, and future uncertainties
# Cannot find Programme Code: ITS4
# ITS4.14/HS12.7  -  Integrated Approaches to Implementing Nature-Based Solutions in Urban Areas
# Cannot find Programme Code: ITS4
# ITS4.16/ERE6.7  -  Participatory and Integrated Approaches for Climate-Resilient Cities: Citizen Science and Adaptation–Mitigation Interdependencies
# Cannot find Programme Code: ITS4
# ITS4.17/CL0.8  -  Climate, Extremes, and Health: Risks and Impacts on Population Health
# Cannot find Programme Code: ITS4
# ITS4.18/CL0.17  -  Population health in a changing climate: past and ongoing impacts, adaptation and future risks
# Cannot find Programme Code: ITS4
# ITS4.19/CL0.10  -  Lethal Heat: Extreme Heat–Humidity Events and Human Health Risks
# Cannot find Programme Code: ITS4
# ITS4.20/CL0.23  -  How to build Resilience? Quantitative and Qualitative Approaches to Understanding and Enhancing Regional Resilience for better withstanding climate impacts
# Cannot find Programme Code: ITS4
# ITS4.21/NH13.5  -  Historical Perspectives on Climate Resilience and Cultural Pyroscapes
# Cannot find Programme Code: ITS4
# ITS4.22/HS12.9  -  Emerging interdisciplinary perspectives in water resilience and risk science: society–ecology–freshwater nexus approaches and socio-meteorology
# Cannot find Programme Code: ITS4
# ITS4.23/CL0.14  -  Opportunities and Challenges in the provision of National Climate Scenarios and Services
# Cannot find Programme Code: ITS4
# ITS4.24/NH13.8  -  Early Warning Systems (EWS): From Science to Action for Effective Disaster Risk Reduction
# Cannot find Programme Code: ITS4
# ITS4.25/NH13.13  -  Marine Geohazards in the Aegean Sea: Transdisciplinary Approaches to Cascading Extreme Events, Early Warning, and Societal Resilience
# Cannot find Programme Code: ITS4
# ITS4.26/CL0.20  -  Inclusive Climate Transition Pathways: Negative Emission Technologies, Social Impacts, and Governance
# Cannot find Programme Code: ITS4
# ITS4.27/NH13.14  -  Dynamics of Climate Risk in the Anthropocene: Integrating Hazards, Exposure and Vulnerability
# Cannot find Programme Code: ITS4
# ITS4.29/NH13.15  -  Advances in Landslide Investigation and Mitigation: Bridging Research and Engineering Geology Practice
# Cannot find Programme Code: ITS4
# ITS4.33/CL0.19  -  Strengthening African–European Partnerships for Global Change Research: From Scientific Capacity to Practical Solutions
# Cannot find Programme Code: ITS4
# ITS4.36/NH13.11  -  Advances in physical climate risk assessment for the financial and insurance sectors
# Cannot find Programme Code: ITS4
# ITS4.37/CL0.13  -  Climate Risk Storylines and Scenarios: From physical modelling to co-production for decision-making
# Cannot find Programme Code: ITS4
#
#  General ITS sessions
# ITS5.1/CL0.6  -  Achievements and perspectives in scientific ocean and continental drilling
# Cannot find Programme Code: ITS5
#
#  Atmospheric Sciences (AS)
# AS1.1  -  Numerical weather prediction, data assimilation and ensemble forecasting
# AS1.2  -  Weather Forecasting and Application
# AS1.3  -  Advances in algorithm design for Numerical Earth System Modelling
# AS1.4  -  Subseasonal prediction, processes and warning capabilities
# AS1.5  -  Developments in Convective-Scale Data Assimilation, Machine Learning, and Observations
# AS1.6  -  Atmospheric convection
# AS1.7  -  Mesoscale and severe convection over land: processes, modelling advances, predictability, and impacts
# NH1.11  -  Atmospheric Electricity, Thunderstorms, Lightning and their effects
# AS1.9  -  Small-scale Cloud Processes
# AS1.10  -  Mixed-phase and ice cloud observations and modelling
# CR5.1  -  Modelling and measuring snow processes across scales
# AS1.12  -  Precipitation: Measurement, Climatology, Remote Sensing, and Modelling
# HS7.1  -  Precipitation variability from drop scale to catchment scale : measurement, processes and hydrological applications
# HS7.2  -  Precipitation modelling: uncertainty, variability, and downscaling
# AS1.15  -  Advancing understanding of the circulation-coupling and Lagrangian evolution of clouds
# CL4.11  -  Climate Sensitivity, Radiative Feedbacks, and the Pattern Effect
# AS1.17  -  The atmospheric water cycle: processes, dynamics, isotopic tracers, and characteristics
# HS7.9  -  The atmospheric water cycle under change: feedbacks, land use, hydrological changes and implications
# AS1.19  -  Extratropical Cyclones, Storms and Diabatic Processes Across Scales: Dynamics, Diagnostics of Observed and Future Trends, and Related Impacts
# AS1.20  -  Atmospheric Rossby waves, Blocking and Jet Stream Dynamics, and their Impacts on Extreme Weather and Climate Events
# NP6.6  -  Lagrangian perspectives on transport and mixing
# AS1.22  -  Internal Gravity Waves
# AS1.23  -  Mountain Weather and Climate: Theory, Observations and Modeling
# AS1.25  -  Transport and exchange processes in the atmosphere over mountains - TEAMx observational campaigns (TOC, HEFEX, PC22)
# AS1.26  -  Tropical Meteorology and Tropical Cyclones
# AS1.27  -  Monsoon systems: processes, prediction, and climatic changes in the past and future
# AS1.28  -  Subtropical weather and climate processes in the past, present, and future
# CR7.3  -  Polar Meteorology, Atmosphere-Cryosphere Interactions and their Links to the Rapidly Changing Climate
# AS1.30  -  Dry-hot compound extremes and its potential tipping cascade risk under global warming
# AS1.31  -  Stratospheric dynamics and its connection to surface weather and climate
# AS1.32  -  Middle atmosphere dynamics: modeling and observations
# AS1.34  -  Atmospheric rivers: Understanding their processes and impacts across past, present, and future climates
# CL4.2  -  The dynamics of the large-scale atmospheric circulation in past, present and future climate
# CL3.1.1  -  Synoptic and Large-Scale Circulation Dynamics: Impacts on Regional Extremes, Climate Variability, and Change
# Cannot find Programme Code: CL3
# AS1.38  -  Extreme Events: Observations and Modeling
# CL3.2.4  -  High-impact climate extremes: from physical understanding and storylines to impacts and solutions
# Cannot find Programme Code: CL3
# ERE2.1  -  Energy Meteorology
# AS2.1  -  Atmospheric Boundary Layer: From Basic Turbulence Studies to Integrated Applications
# AS2.2  -  Air-Land Interactions (General Session)
# AS2.3  -  Surface exchange fluxes above the oceans and at the poles: chemistry, biogeochemistry, physics and climate impacts
# AS3.1  -  Aerosol Chemistry and Physics
# AS3.2  -  Atmospheric organics: Sources, chemistry, and fate
# AS3.3  -  Sources, Formation, and Properties of Organic Aerosols
# AS3.4  -  Bioaerosols: detection, measurements, modelling and impacts
# AS3.5  -  Aeolian dust: initiator, player, and recorder of environmental change
# AS3.6  -  Aerosols, cloud condensation nuclei, ice nucleating particles, and secondary ice production: Impacts on cloud processes and radiative feedbacks
# AS3.7  -  Clouds, Aerosols, Radiation and Precipitation
# AS3.8  -  Bridging Disciplines: Interactions Between Polar Aerosols, Clouds, Sea Ice, and Oceans in a Changing Climate
# AS3.9  -  Anthropogenic and natural aerosols in regional climate change: From physical hazards to climate risk and impacts on nature and society
# AS3.10  -  Interactions between weather/climate and air pollution at present and in the future
# AS3.11  -  EarthCARE’s Second Year in Orbit: Advances in Cloud, Aerosol and Radiation Science
# AS3.12  -  Remote sensing of aerosol and clouds
# AS3.13  -  Satellite observations of tropospheric composition and  pollution, analyses with models and applications
# AS3.14  -  Enhancement of atmosphere characterisation using synergy of multi-instrument remote sensing observations and bridging with transport models and in situ  measurements  (e.g. MIRA)
# CL2.1  -  Earth radiation budget, radiative forcing and climate change
# AS3.16  -  Remote Sensing of Carbon Dioxide and Methane from Space
# AS3.17  -  Quantification and attribution of anthropogenic methane sources through measurement: Where to focus for mitigation?
# AS3.18  -  Methane mitigation technologies: from point source emissions to global sinks
# AS3.20  -  Advances in the measurement and modeling of radicals, reactive halogens, and their precursors in the troposphere
# BG2.2  -  Stable isotopes and novel tracers in atmospheric and biogeosciences
# AS3.22  -  Dynamics and chemistry of the upper troposphere and lower stratosphere (UTLS)
# AS3.23  -  Volcano-climate impacts and the stratospheric aerosol layer
# ST3.2  -  Dynamics, Chemistry, and Coupling in the Middle Atmosphere and MLT Regions
# AS3.26  -  Atmospheric composition variability and trends
# AS3.27  -  The Climate Impacts of a Hydrogen Economy
# AS3.28  -  Urban Air Pollutants in Anthropocene: Composition, Chemistry and Health Impacts
# AS3.29  -  Air Pollution Modelling
# AS3.30  -  Advances in Atmospheric Composition, Air Quality, and Health
# AS3.31  -  Towards sustainable road traffic, shipping and aviation: from emissions to climate and air quality effects
# AS3.32  -  Transport and urban air quality: Characterization and monitoring of real-world emissions, impacts on health, and mitigation strategies
# AS3.33  -  Geo-Ring for Air Quality
# AS3.34  -  Urban air quality, greenhouse gases, and the indoor/outdoor interface
# AS3.35  -  Atmospheric microplastics and nanoplastics
# AS3.37  -  Atmospheric impacts of spacecraft launches and re-entries: knowns, unknowns, and research priorities
# AS3.38  -  Science-based, measurement-based greenhouse gas emission monitoring to inform climate change mitigation across decision-making scales and sectors
# AS3.39  -  Advances in Understanding Atmospheric Chemical and Physical Processes through Theory, Field, Laboratory, Chamber and Molecular Simulation Studies
# AS3.40  -  Integrated Prediction of Weather and Atmospheric Composition
# AS3.41  -  Harmonised atmospheric observations and data-driven receptor modeling for source apportionment and emission assessment of greenhouse gases and air pollution
# AS3.43  -  Aerosol observations and links with atmospheric, climate and solar energy studies; Results of the Harmonia COST Networking Action
# BG1.1  -  The Role of Fire in the Earth System: Interactions with Climate, Biosphere, and Human Systems
# BG1.10  -  Volatile Organic Compounds at the Biosphere-Atmosphere Interface: From Molecular Mechanisms to Global Models
# SM8.2  -  Comprehensive Nuclear-Test-Ban Treaty (CTBT) Monitoring and its civil and scientific applications
# GI2.5  -  Geoscience problems related to radioactive contamination originated from nuclear power plants and other human activities: Chernobyl, Fukushima, and Zaporizhzhia
# AS4.1  -  Extremes, Hydroclimate and Impact of Ocean–Atmosphere Interactions in Semi-Arid Regions
# AS4.2  -  Clouds, moisture, and precipitation in the Polar Regions: Sources, processes and impacts
# CL4.4  -  Land-atmosphere interactions and climate extremes
# AS4.6  -  The atmospheric microbiome – characterization, processes, and connections with Earth’s surface
# AS4.7  -  Linking Climate, Ecosystems, and Atmospheric Chemistry: Interactions and Impacts
# ITS1.19/AS4.8  -  Advancing Environmental sciences with Innovation and Research Infrastructures
# Cannot find Programme Code: ITS1
# AS4.9  -  Atmospheric Science for Action: Connecting Atmospheric Responses to Emissions, Air Quality, Climate, Health, and Environmental Justice to Motivate Policy
# NP1.3  -  Extremes in Geophysical Sciences: Dynamics, Thermodynamics, and Impacts
# NP2.1  -  Complexity, Nonlinearity, and Stochastic Dynamics in the Earth System
# BG10.12  -  From Urban Heat to Flood Risk: Integrating Geospatial Data, Models, and Observations for Green-Blue Adaptation Strategies
# AS5.1  -  AI for Weather and Climate: Opportunities and Challenges
# AS5.2  -  Artificial Intelligence/Machine Learning (AI/ML) in Atmospheric, Climate, and Environmental Sciences: Application and Development
# NP5.1  -  Statistical methods in an era of AI in geosciences: forecasting, verification, and interpretability
# CL5.10  -  AI-driven Forecasting for Weather, Climate, Extreme Events, and related Impacts
# ITS1.13/AS5.5  -  Downscaling: methods, applications and added value
# Cannot find Programme Code: ITS1
# AS5.6  -  Advances in Atmospheric Measurements: From Spectroscopic and Optical Techniques to Novel Modeling Approaches
# CL4.14  -  ​​Earth system models at km-scale and beyond: Benefits and challenges of resolving smaller scale processes
# AS5.9  -  Atmospheric and climate observations by MAX-DOAS, spectral imaging, and uncrewed aircraft systems (UAS)
# AS5.11  -  Low-cost air quality sensors: challenges, opportunities, and collaborative strategies across the world
# GI4.2  -  Lidar remote sensing of the atmosphere
# EOS4.4  -  BUGS: Blunders, Unexpected Glitches, and Surprises
# Cannot find Programme Code: EOS4
# GI2.2  -  Ground-based monitoring networks and Geo-Instrumentation for Natural Physical Processes
# NP1.2  -  The Climate Model Hierarchy: Bridging simulation, understanding and application
# ESSI3.4  -  Scientific software development in the Geosciences: good practices, pitfalls and solutions
# G5.2  -  Atmospheric and Environmental Monitoring with Space-Geodetic Techniques
# SC2.1  -  Compound Events and Multi-Hazard Analytics
# Cannot find Programme Code: SC2
# SC1.1  -  How to navigate EGU: tips and tricks
# Cannot find Programme Code: SC1
# SC2.9  -  Navigating big weather data: An introduction to ECMWF’s MARS data archive
# Cannot find Programme Code: SC2
# SC2.23  -  Using Machine Learning to downscale climate scenarios
# Cannot find Programme Code: SC2
# SC2.21  -  Harnessing cross-disciplinary research - Jupyter Notebooks in EPOS
# Cannot find Programme Code: SC2
# SC2.5  -  Data compression and reduction for Earth System Sciences datasets in practice
# Cannot find Programme Code: SC2
# SC2.18  -  Harnessing the ENVRI-Hub: data, tools, and services for interdisciplinary research
# Cannot find Programme Code: SC2
# SC2.7  -  Getting Started with Data Assimilation: Theory and Application
# Cannot find Programme Code: SC2
#
#  Biogeosciences (BG)
# BG1.1  -  The Role of Fire in the Earth System: Interactions with Climate, Biosphere, and Human Systems
# BG1.2  -  Extreme Fires and their Impacts
# BG1.3  -  Greenhouse gas budgets, trends and variability across scales: observations, models, and emission factors
# BG1.5  -  Global Nitrogen Cycle in the Earth System: Benchmarks, Budgets, Coupled Cycles and Feedbacks
# BG1.6  -  Nitrogen Cycling in the Anthropocene: Microbiological Processes, Land-atmosphere- Interactions and Global Change Feedbacks
# BG1.7  -  Recent advances in phosphorus cycling: from micro to global scale
# BG1.10  -  Volatile Organic Compounds at the Biosphere-Atmosphere Interface: From Molecular Mechanisms to Global Models
# BG1.11  -  Functional diversity in motion: ecological and evolutionary drivers of biogeochemical processes across terrestrial, aquatic and atmospheric systems
# BG1.13  -  Urban Ecosystems, human health and well-being: A way towards sustainability
# NP3.3  -  Extreme variability across scales, from theory to applications
# NH7.1  -  Spatial and Temporal Dynamics of Wildfires: Models, Theory, and Reality
# AS2.2  -  Air-Land Interactions (General Session)
# AS2.3  -  Surface exchange fluxes above the oceans and at the poles: chemistry, biogeochemistry, physics and climate impacts
# AS3.5  -  Aeolian dust: initiator, player, and recorder of environmental change
# SC1.1  -  How to navigate EGU: tips and tricks
# Cannot find Programme Code: SC1
# AS4.7  -  Linking Climate, Ecosystems, and Atmospheric Chemistry: Interactions and Impacts
# BG2.1  -  Application of Stable Isotopes in Biogeosciences
# BG2.2  -  Stable isotopes and novel tracers in atmospheric and biogeosciences
# BG2.4  -  Novel methods for bridging understanding of carbon, nitrogen, and water fluxes from leaf to continental scales
# BG2.7  -  Lipid biomarkers: novel applications, calibrations and tools for environmental studies
# BG2.10  -  Approaches to measuring, processing and understanding the exchange of gases in soils and ecosystems
# BG3.1  -  Terrestrial ecosystem responses to global change: integrating experiments, ecosystem observations, and models to understand carbon, nutrient, and water cycling
# BG3.2  -  Emerging constraints of photosynthesis, respiration and transpiration at ecosystem to global scales
# BG3.3  -  Plant traits, adaptation, and biogeochemical cycles – from measurements to models
# BG3.4  -  Present and future global vegetation dynamics and carbon stocks from observations and models
# BG3.5  -  Improving model representation of ecosystem processes and climate responses
# BG3.7  -  Land use, land management, and land cover change (LULCC) and their effects on the Earth system
# BG3.8  -  Advancing Ecosystem Research: Responses to Climate Change and Anthropogenic Influences Using Experimental, Observational, and Modeling Approaches
# BG3.11  -  Natural forest expansion and satellite biodiversity monitoring under global change
# BG3.12  -  Nature-based solutions for restoring forests under climate change
# BG3.13  -  Enhancing science-based knowledge on forests’ capacities to mitigate climate change
# BG3.14  -  Drylands under global change: applications, challenges, and opportunities for monitoring land surface components and biogeochemical cycling
# BG3.15  -  Forest methane (CH4) and nitrous oxide (N2O) cycles
# BG3.17  -  Cold regions in a changing climate:  ecosystem dynamics across seasons
# BG3.19  -  Paludiculture, peatland management and restoration from the boreal zone to the tropics
# BG3.20  -  Oxidation of Peat Carbon: From Process to Emissions
# BG3.21  -  Exchange of GHG and reactive gases in agricultural ecosystems
# BG3.22  -  Modeling agricultural systems under global change
# BG3.23  -  Soil Management Effects on Carbon and Nitrogen Cycling and Soil Functions in Subsoils and in Grassland Soils
# BG3.25  -  Plant-Soil Systems in a Changing World
# HS8.3.4  -  Soil-Plant Interactions and Soil Biophysics
# Cannot find Programme Code: HS8
# BG3.27  -  Mycorrhizal fungi in natural ecosystems
# BG3.28  -  Functional roles and biogeochemical cycling of cryptogamic/microbial communities in a globally changing environment
# BG3.29  -  Root Exudates: Form and Function in the Rhizosphere and Beyond
# BG3.30  -  Soil nitrogen transformations – advances in quantification and process-based modelling
# SSS4.1  -  Microbial life, metabolism and death in soil: new insights into C cycling and soil function
# BG3.36  -  Ecosystem Responses to Stresses and Climate Extremes: Vegetation and Biogeochemical Processes
# BG3.37  -  Impacts of climatic extremes on plants and ecosystems across scales
# BG3.38  -  Climate change, drought and forest dieback: mechanisms, gaps, and forward-looking research
# BG3.39  -  Tropical Forests in Transition: Disturbance, Recovery, and Resilience
# BG3.41  -  Microclimate Variation and Heat Impacts on Vegetation: From Molecules to the Biosphere
# BG3.42  -  Missing links in drought research: connecting plant-water interactions across scales
# BG3.43  -  Observing Plant Hydraulics Across Scales and Perspectives: Methods and Use Cases
# BG3.44  -  Complex case studies for ecosystem responses to global change, climate and hydrological extremes
# CL4.4  -  Land-atmosphere interactions and climate extremes
# HS10.5  -  Ecohydrological responses to droughts in a changing environment: Mechanism, trends and impacts
# BG4.1  -  Aquatic biogeochemical cycles: From field and lab measurements to understanding patterns and processes in past, present, and future aquatic environments
# BG4.3  -  Greenhouse gas dynamics and fluxes in aquatic ecosystems
# BG4.4  -  Dynamics of Greenhouse Gases (CH4, N2O, CO2) in Aquatic Environments
# BG4.5  -  Beyond Blue Carbon: Interdisciplinary insights into coastal ecosystem dynamics
# HS1.1.1  -  Pushing the boundaries of field hydrology
# Cannot find Programme Code: HS1
# HS10.7  -  Stable isotopes to study water and nutrient dynamics in the soil-plant-atmosphere continuum
# HS10.12  -  From water to waterscape: multi-scale processes across wetlands and waterbodies
# OS2.3  -  Coastal dynamics and processes under changing climate and changing human activities.
# OS1.10  -  Understanding the Indian Ocean's past, present and future
# OS4.3  -  Advances in Ocean Coastal Monitoring and Forecasting
# GI4.3  -  Monitoring of water systems and related habitats
# BG5.1  -  Biogeodynamics and the co-evolution of Earth, climate and life
# CL1.1.1  -  Past climate change and carbon cycle: insights from models and proxies
# Cannot find Programme Code: CL1
# CL1.2.3  -  Speleothem and karst records - Reconstructing terrestrial climatic and environmental change
# Cannot find Programme Code: CL1
# CL4.16  -  Isotopic and multi-proxy continental, atmospheric, marine and ice records at various time scales; Special bloc on Earth’s oxygenation events
# CL1.2.9  -  Oceanic and atmospheric drivers of Quaternary (sub)tropical South American climate and vegetation
# Cannot find Programme Code: CL1
# CL4.15  -  Climate impacts on terrestrial life: faunal responses and vegetation dynamics from past to future
# SSP4.5  -  Paleoclimate and paleoenvironment through the lens of micropaleontology and actuopaleontology
# SC2.2  -  Integration of eDNA in Geoscience Research
# Cannot find Programme Code: SC2
# SSS4.4  -  Soil health under global change and human activities
# SSS4.3  -  Microbial responses to global change: from physiology to ecosystem feedbacks
# SSS4.2  -  Emerging approaches to understanding diverse soil microbial interactions that drive biogeochemical cycles in a changing world
# SSP3.11  -  (Bio)mineralization and diagenetic processes: insights from experiments, modern environments and the geological record
# BG7.1  -  Biogeomagnetism: From Geomagnetic Field to Planetary Habitability
# PS6.3  -  Impacts and their role in the evolution of Life
# BG8.1  -  When Murphy’s Law Meets Climate Hazards – Cascading Risks and Unprepared Futures
# BG8.3  -  From Long-Term Flux Observation and Ecosystem Research Networks to Individual Applications - Benefits to Science and Society
# BG8.5  -  Being Climate- and Biodiversity-smart: pathways for sustainable and resilient forestry and implications for ecosystems, hydrology, and society
# BG8.7  -  Nature-based and Innovative Solutions For Water Quality Challenges
# AS3.38  -  Science-based, measurement-based greenhouse gas emission monitoring to inform climate change mitigation across decision-making scales and sectors
# CL3.2.1  -  Towards net zero and beyond: Carbon Budgets, Overshoot, Climate (Ir)reversibility, and Carbon Removal
# Cannot find Programme Code: CL3
# BG8.11  -  Peatland mapping, monitoring and greenhouse gas accounting at national and international scales
# BG9.1  -  Remote Sensing and Model-Data Fusion Applications for the Biosphere
# BG9.4  -  Remote Sensing for forest applications
# BG9.6  -  Satellite Observations for Wetland Dynamics and Ecosystem Monitoring
# BG9.7  -  Large-scale mapping of environmental variables by combining ground observations, remote sensing, and machine learning
# BG9.9  -  Data science, earth observation and AI for sustainable agroecosystem monitoring and management
# BG9.10  -  Advances in regional crop modeling and integration of remote sensing data
# GM2.5  -  From historical images to modern high resolution topography: methods and applications in geosciences
# HS6.5  -  Remote Sensing for Surface Water and Flood Dynamics Mapping and Monitoring
# ESSI2.7  -  Workflow approaches enabling scalable and reproducible state-of-the-art computation and data analysis in Earth System Sciences
# CL5.8  -  Crosscutting Advances in Land Surface Modelling: the Climate-Hydrology-Ecosystem Nexus, Compound Extremes and Transitions
# SC2.22  -  See the Flames from Space: Hands-on Wildfire Visualization with EUMETView and GIS
# Cannot find Programme Code: SC2
# ...
# EMRP3.2  -  Rock Magnetism Frontiers: Multiscale Insights into Earth and Beyond
# GMPV7.1  -  Deep roots, pulsed magmatism, and global impacts: origins, temporality, and consequences of hotspots and Large Igneous Provinces
# BG5.1  -  Biogeodynamics and the co-evolution of Earth, climate and life
# SSP4.4  -  Macrofossil remains and geochemical proxies as high-resolution archives of past environmental change
# SSP4.5  -  Paleoclimate and paleoenvironment through the lens of micropaleontology and actuopaleontology
#
#  Soil System Sciences (SSS)
# EOS1.1  -  Science and Society: Science Communication Practice, Research, and Reflection
# Cannot find Programme Code: EOS1
# EOS1.4  -  How to communicate uncertainty to non-experts
# Cannot find Programme Code: EOS1
# SSS2.1  -  Measuring, modelling, and managing soil erosion: what works, what doesn’t, and how to move forward?
# SSS2.3  -  Gully and rill erosion: recent advancements and novel approaches
# SSS2.4  -  Soil Erosion, Land Degradation and Conservation
# HS9.6  -  Sediment Dynamics and Watershed Management under Environmental and Climate Change
# BG2.7  -  Lipid biomarkers: novel applications, calibrations and tools for environmental studies
# GM4.4  -  New perspectives in geoarchaeology: human agency, landscape change and how they shaped the late Quaternary
# GM6.2  -  Dryland evolution: Paleoenvironmental, geomorphic and geoarchaeological perspectives
# SSS4.1  -  Microbial life, metabolism and death in soil: new insights into C cycling and soil function
# SSS4.2  -  Emerging approaches to understanding diverse soil microbial interactions that drive biogeochemical cycles in a changing world
# SSS4.3  -  Microbial responses to global change: from physiology to ecosystem feedbacks
# SSS4.4  -  Soil health under global change and human activities
# SSS4.7  -  Plant - microbial interactions at soil interfaces: scaling from nano-habitats to ecosystem processes
# BG3.29  -  Root Exudates: Form and Function in the Rhizosphere and Beyond
# SSS5.2  -  Soil organic matter dynamics and biogeochemical cycles across scales: mechanisms, spatial heterogeneity and implications
# SSS5.4  -  Carbon sequestration in soils: organic and inorganic mechanisms of increasing soil carbon stocks as a pathway to net zero and improved soil functioning
# SSS5.5  -  Biogeochemical and redox controls on carbon, nitrogen, phosphorus, and sulfur cycling in the critical zone
# SSS5.6  -  Advances in Enhanced Weathering: Carbon Removal, Co-benefits, and Risks
# SSS5.7  -  Unraveling Soil Organic Matter Persistence: Mechanisms, Models, and Management Implications across Ecosystems
# BG1.7  -  Recent advances in phosphorus cycling: from micro to global scale
# BG1.11  -  Functional diversity in motion: ecological and evolutionary drivers of biogeochemical processes across terrestrial, aquatic and atmospheric systems
# BG3.15  -  Forest methane (CH4) and nitrous oxide (N2O) cycles
# BG3.23  -  Soil Management Effects on Carbon and Nitrogen Cycling and Soil Functions in Subsoils and in Grassland Soils
# SSS6.1  -  Measurement and Modeling of Soil Processes Across Scales
# SSS6.4  -  Linking soil structure dynamics and soil mechanical properties to soil functioning
# SSS6.8  -  Next-Generation Soil Physics: Measuring and Modeling the Soil–Plant–Atmosphere Continuum through Remote Sensing, Artificial Intelligence, and Process-Based Approaches
# SSS6.10  -  Soils, Nature Based Solutions, and Spatial Planning for Climate-Resilient Landscapes
# NH3.3  -  Investigations of landslides and unstable slopes - perspectives, opportunities and latest trends in geophysical, geotechnical, and remote sensing studies
# HS8.3.5  -  Back to the soil—water constitutive laws: Where modeling meets Physics
# Cannot find Programme Code: HS8
# HS8.3.3  -  Hydrological processes and contaminants transport in the vadose zone: Recent developments and novel insights
# Cannot find Programme Code: HS8
# SM6.5  -  Geophysical imaging of near-surface structures and processes
# SSS7.1  -  Plastic in soils - where do we stand?
# SSS7.2  -  From Soil to Society: Traditional field-based methods and Remote Sensing for the Assessment of Soil Degradation and Environmental and Human Health Risks
# SSS7.5  -  Tracing Soil Contamination and Recovery: Tools, Indicators, and Case Studies
# HS9.7  -  Soil Erosion, Sediment, and Contaminant Dynamics across the Land-River-Lake Continuum: Advances in Monitoring, Modelling, and Management
# SSS8.2  -  Land management and their relations to soil water retention potentials due to changes in vegetation and soil physical-chemical characteristics, from field to watershed scale
# SSS8.4  -  Soil health and ecosystem services in orchards and vineyards: management, monitoring, and modelling
# HS2.1.9  -  Critical Zone Science Around the World: Innovations, Experiments, and Collaborative Efforts
# Cannot find Programme Code: HS2
# BG4.5  -  Beyond Blue Carbon: Interdisciplinary insights into coastal ecosystem dynamics
# BG3.17  -  Cold regions in a changing climate:  ecosystem dynamics across seasons
# SSS9.1  -  Adaptation and resilience in agriculture: addressing climate change with science and technology
# SSS9.2  -  Advances in Nutrient Management Strategies for Soil and Water Conservation
# SSS9.3  -  Soil organic and inorganic carbon and nutrient monitoring and modelling in natural and agroecosystems
# SSS9.4  -  Soil organic amendments: implications for soil health and nutrient dynamics in a circular economy framework
# SSS9.6  -  Soil, landforms and ecosystems coevolution under global perturbances: degradation, resilience, and conservation practices
# SSS9.9  -  Managing wildfires in a changing world
# BG3.12  -  Nature-based solutions for restoring forests under climate change
# BG8.5  -  Being Climate- and Biodiversity-smart: pathways for sustainable and resilient forestry and implications for ecosystems, hydrology, and society
# NH7.1  -  Spatial and Temporal Dynamics of Wildfires: Models, Theory, and Reality
# HS6.8  -  Irrigation estimate and management from remote sensing and agro-hydrological modelling
# SSS9.14  -  The irrigation challenges to tackle uncertainty in water resources
# SSS10.3  -  Bridging scales in the soil-plant-atmosphere continuum: Integrating observations and physics-informed modelling for Earth System resilience
# SSS10.5  -  Monitoring Soil and Water in the Era of Global Change
# SSS10.6  -  Digital Soil Mapping and Assessment using Pedometrics approaches and remote sensing
# SSS10.9  -  Soil health assessment across scales: from reference frameworks and indicators to harmonised monitoring, data integration and societal uptake
# HS8.3.1  -  Advancing the monitoring, maintenance and utilization of in situ soil moisture
# Cannot find Programme Code: HS8
# SSS11.1  -  Organic petrographic techniques for biochar characterization and performance evaluation
# SSS11.2  -  Exploring the link between sediment connectivity and sustainable watershed management: methods, strategies, and challenges
# EOS4.4  -  BUGS: Blunders, Unexpected Glitches, and Surprises
# Cannot find Programme Code: EOS4
# HS8.3.4  -  Soil-Plant Interactions and Soil Biophysics
# Cannot find Programme Code: HS8
# HS8.2.13  -  Multiscale Perspectives on Groundwater Recharge: From Field Observations to Integrated Models
# Cannot find Programme Code: HS8
# GM2.5  -  From historical images to modern high resolution topography: methods and applications in geosciences
# SSS12.2  -  Future EU Soil Monitoring and Resilience Directive : scientific challenges and research opportunities
# EOS4.1  -  Geoethics: Linking Geoscience Knowledge, Ethical Responsibility, and Action
# Cannot find Programme Code: EOS4
# SC1.1  -  How to navigate EGU: tips and tricks
# Cannot find Programme Code: SC1
# SC2.22  -  See the Flames from Space: Hands-on Wildfire Visualization with EUMETView and GIS
# Cannot find Programme Code: SC2
# SC2.23  -  Using Machine Learning to downscale climate scenarios
# Cannot find Programme Code: SC2
#
#  Solar-Terrestrial Sciences (ST)
# ST1.1  -  Open session on the Sun and Heliosphere
# ST1.3  -  Solar Orbiter: A new perspective on the Sun and the heliosphere
# ST1.4  -  Exploring the Solar Corona in unprecedented detail
# ST1.6  -  Observing and modelling coronal mass ejections from the Sun to the heliosphere
# ST1.7  -  Collisionless shocks and associated transient phenomena at Earth and beyond
# ST1.8  -  Acceleration and Transport of Suprathermal and Energetic Particles in the Heliosphere
# ST1.9  -  The Sun, the heliosphere, and the local interstellar medium: Novel insights on their interaction and first results from NASA IMAP
# PS4.1  -  Planetary, Solar and Heliospheric Radio Emissions
# NP6.3  -  Turbulence, magnetic reconnection, shocks and particle acceleration: nonlinear processes in space, laboratory and astrophysical plasmas
# NP6.1  -  Turbulence in Space Plasmas: Structures, Waves, and Dissipation
# SC1.1  -  How to navigate EGU: tips and tricks
# Cannot find Programme Code: SC1
# ST2.1  -  Open Session on the Magnetosphere
# ST2.2  -  Unveiling plasma energisation and energy transport in space plasmas through multiscale observations and advanced numerical modelling
# ST2.3  -  Magnetic reconnection and Kelvin-Helmholtz Instability in collisionless environments
# ST2.4  -  Regimes of wave-particle interactions in terrestrial and planetary magnetospheres and the solar wind
# ST2.6  -  Multiscale Solar Wind–Magnetosphere–Ionosphere Coupling: Observations, Simulations, and Modeling
# ST2.9  -  Inner Magnetosphere, Ionosphere, and Atmosphere Coupling
# GI4.7  -  Cosmic rays across scales and disciplines: the new frontier in environmental research
# ST3.1  -  Open Session on the Ionosphere and Thermosphere
# ST3.2  -  Dynamics, Chemistry, and Coupling in the Middle Atmosphere and MLT Regions
# EMRP2.6  -  LEO satellites for Exploring the near-Earth Magnetic Field and the Ionosphere-Thermosphere Environment
# ST3.6  -  Polar and midlatitude ionosphere–atmosphere studies through ground-based observations
# GI4.2  -  Lidar remote sensing of the atmosphere
# ST4.1  -  Open Session on Space Weather and Space Climate
# ST4.2  -  Nowcasting, forecasting, operational monitoring, and post-event analysis of space weather and space climate in the Sun-Earth system
# ST4.6  -  Models, missions, and instruments used to understand extreme space weather and to forecast its effects
# PS4.2  -  Space Environments of Unmagnetized or Weakly Magnetized Solar System Bodies and the Effects of Space Weather on These Systems
# AS3.37  -  Atmospheric impacts of spacecraft launches and re-entries: knowns, unknowns, and research priorities
# ESSI1.18  -  Machine Learning in Planetary Sciences and Heliophysics
#
#  Tectonics & Structural Geology (TS)
# TS1.1  -  Brittle and ductile deformation of Earth’s lithosphere: Mechanisms governing deformation style
# TS1.2  -  Deformation in detail: high-resolution imaging and textural analysis of Earth materials
# TS1.5  -  Fluid-rock interactions: interplays, processes and tracers
# TS1.6  -  Fluid Flow and Rock Interaction Across Scales: From Grains to Plates
# TS1.8  -  Seismic and aseismic fault deformation
# TS1.9  -  All about fractures: multi-scale and multidisciplinary approaches to the characterisation of fractured rock masses
# TS2.1  -  Rift evolution: from continental inception to seafloor spreading
# TS2.3  -  4-D architectural, kinematical and mechanical evolution of continental and oceanic low-angle normal faults and detachments
# TS2.4  -  The Role of Structural, Thermal, and Chemical Inheritance During Positive and Negative Tectonic Inversion
# TS2.5  -  Tectonics and geodynamic evolution of the Alpine-Mediterranean region
# TS2.6  -  The Trans-Atlantic connection of Iapetus and Rheic ocean closures in the Paleozoic
# GD2.1  -  Initiation and evolution of subduction: dynamics, volatiles and melts from the surface to the deep mantle
# GD2.4  -  Subduction and Plate Boundary Geodynamics in the Americas
# GD2.3  -  Magmatic, hydrothermal and tectonic processes at mid-oceanic ridges and oceanic transform faults: new insights from observations, experiments and numerical modelling
# TS3.1  -  Studying Active Faults from the Near-Surface to Seismogenic Depth: Advances and Open Questions in Seismotectonics and Active Tectonic Processes
# TS3.2  -  Across the time scales, from earthquakes to earthquake cycle
# TS3.3  -  From Fault Systems to Fault Patch: what controls fault deformation across spatial and temporal scales
# TS3.4  -  Linking seismicity and tectonic processes at subduction and collision zones
# TS3.5  -  Subduction Zone Observation through Time, Space and Scales: a multidisciplinary initiative
# TS3.6  -  Continental Deformation and Seismic Strain Accumulation
# TS3.7  -  Active Tectonics and Geodynamics of the Eastern Mediterranean
# SM4.3  -  A comprehensive understanding of slow earthquakes
# SM8.1  -  Advancing Earthquake Rupture Forecast and Seismic Hazard Assessment through Multidisciplinary Fault Studies
# TS4.1  -  Interactions of geodynamic and surface processes II: Shaping Orogens Through Space and Time
# TS4.2  -  Interactions of geodynamic and surface processes I:  Orogen-sedimentary basin systems
# GM7.1  -  Interactions between tectonics, climate and surface processes from mountain belts to basins
# TS6.1  -  Understanding Low-strain and Intraplate regions seismogenic sources and Quaternary deformation
# TS7.1  -  Continental Formation, Growth and Reworking: The Dynamic Engine of Earth System Evolution
# TS8.2  -  Stress in the crust  – quantification, modelling and uncertainties
# ERE5.2  -  Faults and fractures in geoenergy applications: Monitoring, laboratory, field work and modelling results
# GMPV3.1  -  Understanding fluid-rock interactions of ultramafic rocks for CO2 mineralization, natural H2 resources and critical element mobility
# ERE1.8  -  Multi-scale subsurface processes, fluid systems and raw materials supporting the energy transition: scientific challenges and interdisciplinary approaches
# ERE5.6  -  Geo-modelling for the Future: Advances in Structural and Reservoir Modelling for the Energy Transition
# TS9.1  -  Tectonics and Structural Geology in a Changing World
# EOS4.4  -  BUGS: Blunders, Unexpected Glitches, and Surprises
# Cannot find Programme Code: EOS4
# GD1.1  -  Mantle and Core of the Earth; structure, dynamics and interactions
# GD2.2  -  Towards New Understandings in Wilson Cycle Processes
# GD3.1  -  Anisotropy from crust to core: Observations, models and implications
# GD2.5  -  Geodynamics of Southeast Asia
# GM2.4  -  Dates, Rates and Bytes: advances in cosmogenic nuclides and other geochronological techniques to quantify surface processes and landscape dynamics
# GMPV2.2  -  Advances in Geochronology and Thermochronology: from traditional methods to avant-garde applications
# GMPV4.1  -  Decoding Earth's Crustal Engine: Integrated Petrochronology and Structural Constraints on 4-D Tectono-Metamorphic Evolution
# GMPV5.2  -  Formation of metal ore deposits during fluid-rock interactions: from physical patterns, chemical reaction to numerical modelling
# GMPV8.1  -  To see a world in a grain of rock: Decoding metamorphic, magmatic, and ore mineralisation processes using rock textures and microstructures
# GMPV10.12  -  Volcanic processes: tectonics, deformation, geodesy, unrest
# GMPV12.1  -  Advances in computational modelling, data analysis, and visualisation in GMPV
# PS1.3  -  Earth is a planet: contribution of planetary science to understanding the Earth systems
# SM2.4  -  Physics-based earthquake modeling and engineering
# SM3.4  -  Fibre-optic sensing in the Geosciences
# SM4.4  -  Why do we hear silent slip? Unraveling the link between aseismic slip and its seismic manifestation
# SM6.4  -  Advances in Seismic Attenuation, Scattering, and Absorption
# SM6.1  -  Joint modelling and inversion of multi-disciplinary geophysical datasets: crust and lithosphere
# SC1.1  -  How to navigate EGU: tips and tricks
# Cannot find Programme Code: SC1
# SC2.17  -  Hands-on 3D landslide mapping
# Cannot find Programme Code: SC2

# %%
df_final = pd.concat([df_keynotes, df_union_wide, df_community, df_trans, df_disciplinary], ignore_index=True)

# %%
df_final.to_excel('egu_schedule.xlsx', index=False)
